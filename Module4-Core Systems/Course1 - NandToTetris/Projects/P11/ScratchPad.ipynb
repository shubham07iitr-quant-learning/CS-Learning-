# %%
with open ("test.jack") as file:
    listall = file.readlines()

print(listall)
# Out:
# ['// This is a single line comment\n', '\n', '/**\n', ' * Represents a simple calculator.\n', ' * Provides basic arithmetic operations.\n', ' */\n', 'class Calculator {\n', '    field int result;\n', '    static int count;\n', '\n', '    /* A simple block comment */\n', '    constructor Calculator new(int initialValue) {\n', '        let result = initialValue;\n', '        let count = count + 1;\n', '        return this;\n', '    }\n', '\n', '    /** Adds a value to the current result. */\n', '    method int add(int x) {\n', '        let result = result + x;\n', '        return result;\n', '    }\n', '\n', '    method void printResult() {\n', '        // printing the result\n', '        do Output.printString("Result: ");\n', '        do Output.printInt(result);\n', '        do Output.println();\n', '        return;\n', '    }\n', '\n', '    method boolean isPositive() {\n', '        if (result > 0) {\n', '            return true;\n', '        } else {\n', '            return false;\n
# ...

# %%
finalList = []
for i in listall:
    if i[:2] == "//" or i == "\n":
        continue
    
    else:
        finalList.append(i)
print(finalList)
# Out:
# ['/**\n', ' * Represents a simple calculator.\n', ' * Provides basic arithmetic operations.\n', ' */\n', 'class Calculator {\n', '    field int result;\n', '    static int count;\n', '    /* A simple block comment */\n', '    constructor Calculator new(int initialValue) {\n', '        let result = initialValue;\n', '        let count = count + 1;\n', '        return this;\n', '    }\n', '    /** Adds a value to the current result. */\n', '    method int add(int x) {\n', '        let result = result + x;\n', '        return result;\n', '    }\n', '    method void printResult() {\n', '        // printing the result\n', '        do Output.printString("Result: ");\n', '        do Output.printInt(result);\n', '        do Output.println();\n', '        return;\n', '    }\n', '    method boolean isPositive() {\n', '        if (result > 0) {\n', '            return true;\n', '        } else {\n', '            return false;\n', '        }\n', '    }\n', '    method int compute(int a, int b) {
# ...

# %%
a = ["<symbol> ( </symbol>", "<whileStatement> while </whileStatement>", "<identifier> sum </identifier>"]

# %%
with open("scratch.xml", "w") as file:
    for i in a:
        file.write(i + "\n")

# %%
a = "Main.jack"
a[-5:]
# Out:
# '.jack'
